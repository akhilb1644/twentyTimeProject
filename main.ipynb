# %%
import plotly.graph_objects as pgo
import pandas as pd
import json

class Attraction:
    def __init__(self,name,interest,state,lat,long):
        self.name = name
        self.interest = interest
        self.state = state
        self.lat = lat
        self.long = long
    
    def __str__(self):
        return f"Name: {self.name} Interest {self.interest} State {self.state} Latitude {self.lat} Longitude {self.long}"
        
lats = list()
lons = list()
texts = list()

lats1 = list()
lons1 = list()
texts1 = list()

lats2 = list()
lons2 = list()
texts2 = list()
        
mapAttractions = list()
states = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# %%
with open('hikingCoords.json') as c:
    coords = json.load(c)
    
coordsList = list()
for coord in coords.values():
    coordsList.append(coord)
    
print(coordsList)
print(len(coordsList))
# Out:
# [[34.97694676259723, -86.08163777105284, 33.336377407067964, -86.73177905525269, 33.48327494207824, -85.81040480383025], [63.10603224618269, -151.1893243974021, 61.29920862378132, -149.5883643703269, 59.84775895833667, -150.1746690763698], [34.99838226663128, -111.6680350402417, 33.5213128237039, -111.97335518626899, 34.937074755514836, -111.79441138156773, 33.46299204472307, -111.4806638885764, 33.56145361494517, -112.020481593635, 33.659442805266906, -111.83737107215292, 33.475406247086866, -111.1935445714791, 36.267455633110195, -112.3534719179329, 37.00132173248122, -111.42186185051393, 34.81455640192218, -111.69974796331282, 35.34069837181008, -111.69318217517255, 33.344270290867115, -112.0710976121517, 32.32076568348906, -110.81162035415686, 33.858837501246185, -111.3455507840709], [35.68271564321374, -93.17217894922523, 35.86674963899576, -93.21437834401254, 34.43244176245793, -92.91232692634047], [37.865360900248085, -119.53594335385844, 33.00457814658036, -116.99483430616195
# ...

# %%
with open('hiking.json') as h:
    attractions = json.load(h)
    
attractionList = list()
for attraction in attractions.values():
    attractionList.append(attraction)
    
print(attractionList)
print(len(attractionList))
# Out:
# [['Walls of Jericho Trail', 'Oak Mountain State Park', 'Cheaha State Park'], ['Denali National Park', 'Chugach State Park', 'Kenai Fjords National Park'], ['Coconino National Forest', 'Echo Canyon Recreation Area', 'Red Rock-Secret Mountain Wilderness', 'Lost Dutchman State Park', 'Phoenix National Preserve', 'McDowell Sonoran Preserve', 'Superstition Wilderness', 'Grand Canyon National Park', 'Glen Canyon National Recreation Area', 'Munds Mountain Wilderness', 'Kachina Peaks Wilderness', 'South Mountain Preserve', 'Sabino Canyon Recreation Area', 'Tonto National Forest'], ['Ozark-St. Francis National Forest', 'Buffalo National River', 'Lake Catherine State Park'], ['Yosemite National Park', 'Mt. Woodson Trail', 'Mission Peak Regional Preserve', 'Point Lobos State Natural Reserve', 'Torrey Pines State Natural Reserve', 'Angeles National Forest', 'Golden Gate National Recreation Area', 'Santa Monica Mountains National Recreation Area', 'Eaton Canyon', 'Iron Mountain Trail', 'John Muir
# ...

# %%
sIndex = 0
for state in attractionList:
    index = 0
    for attraction in state:
        a = Attraction(attraction,"Hiking",states[sIndex],coordsList[sIndex][index*2],coordsList[sIndex][index*2+1])
        mapAttractions.append(a)
        index += 1
    sIndex += 1

# %%
visits = list()

with open('khrushchev.json') as k:
    cold = json.load(k)
    
with open('khrushchevCoords.json') as kc:
    coldCoords = json.load(kc)
    
kCoords = list(coldCoords.values())
kStates = list(cold.keys())
index = 0
for visit in cold.values():
    v = 0
    for value in visit:
        visits.append(Attraction(value,"Khrushchev's Visit",kStates[index],kCoords[index][v*2],kCoords[index][v*2+1]))
        v += 1
    index += 1
    
print(visits)
# Out:
# [<__main__.Attraction object at 0x00000262D3073A30>, <__main__.Attraction object at 0x00000262D3867EB0>, <__main__.Attraction object at 0x00000262D3867070>, <__main__.Attraction object at 0x00000262D3867D60>, <__main__.Attraction object at 0x00000262D3867E20>, <__main__.Attraction object at 0x00000262D3867AF0>, <__main__.Attraction object at 0x00000262D37DFCD0>, <__main__.Attraction object at 0x00000262D37DF790>, <__main__.Attraction object at 0x00000262D37DF520>, <__main__.Attraction object at 0x00000262D0B3F100>, <__main__.Attraction object at 0x00000262D0B3F190>, <__main__.Attraction object at 0x00000262D0B3FD90>]

# %%
karts = list()

with open('goKarts.json') as oka:
    rub = json.load(oka)
    
with open('goKartsCoords.json') as rts:
    rubCoords = json.load(rts)
    
gCoords = list(rubCoords.values())
gStates = list(rub.keys())
f = 0
for goKart in rub.values():
    w = 0
    for eman in goKart:
        karts.append(Attraction(eman,"GoKarts",gStates[f],gCoords[f][w*2],gCoords[f][w*2+1]))
        print(gStates[f])
        w += 1
    f += 1
    
for kart in karts:
    print(kart.name)
# Out:
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alaska
# Alaska
# Alaska
# Alaska
# Alaska
# Alaska
# Alaska
# Arizona
# Arizona
# Arizona
# Arizona
# Arizona
# Arizona
# Arkansas
# Arkansas
# Arkansas
# Arkansas
# Arkansas
# Arkansas
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# California
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Colorado
# Connecticut
# Connecticut
# Connecticut
# Connecticut
# Connecticut
# Connecticut
# Delaware
# Delaware
# Delaware
# Delaware
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Florida
# Georgia
# Georgia
# Georgia
# Georgia
# Georgia
# Georgia
# Hawaii
# Hawaii
# Idaho
# Idaho
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# ...

# %%
for at in mapAttractions:
    lats.append(at.lat)
    lons.append(at.long)
    texts.append(at.name + "---State: " + at.state)
    
for att in visits:
    lats1.append(att.lat)
    lons1.append(att.long)
    texts1.append(att.name + "---State: " + att.state)
    
for attr in karts:
    lats2.append(attr.lat)
    lons2.append(attr.long)
    texts2.append(attr.name + "---State: " + attr.state)

mapdata = [
pgo.Scattergeo(
    lat=lats,
    lon=lons,
    mode='markers',
    text = texts,
    name = "Hiking Attractions"
),pgo.Scattergeo(
    lat=lats1,
    lon=lons1,
    mode='markers',
    text = texts1,
    name = "Khrushchev's visit(simpified)"
),pgo.Scattergeo(
    lat=lats2,
    lon=lons2,
    mode='markers',
    text = texts2,
    name = "GoKart Locations"
)]

fig = pgo.Figure(data = mapdata)

fig.update_geos(center_lat=44.96504742388492,center_lon=-103.77264795846477,projection_scale=2.5,showcountries=True,showsubunits=True,showrivers=True)

fig.show()
fig.write_html('map.html')
# Out:
# <div>                            <div id="53793174-f1d6-45f6-9e09-c9085212cd9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53793174-f1d6-45f6-9e09-c9085212cd9f")) {                    Plotly.newPlot(                        "53793174-f1d6-45f6-9e09-c9085212cd9f",                        [{"lat":[34.97694676259723,33.336377407067964,33.48327494207824,63.10603224618269,61.29920862378132,59.84775895833667,34.99838226663128,33.5213128237039,34.937074755514836,33.46299204472307,33.56145361494517,33.659442805266906,33.475406247086866,36.267455633110195,37.00132173248122,34.81455640192218,35.34069837181008,33.344270290867115,32.32076568348906,33.858837501246185,35.68271564321374,35.86674963899576,34.43244176245793,37.865360900248085,33.00457814658036,32
# ...
